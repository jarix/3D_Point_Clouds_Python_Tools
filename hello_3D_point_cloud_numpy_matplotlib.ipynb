# %% [markdown]
# # Hello 3D Point Cloud from file Visualized with Matplotlib 3D plot

# %%
# Prerequisites and Dependencies

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Load Data

# %%
# Load a point cloud

file_path = 'point_clouds_synthetic/duck_rainbow.xyzrgb'

pc = np.loadtxt(file_path)

mean_Z = np.mean(pc, axis=0)[2]
print(f'Mean Z value: {mean_Z}')
# Out:
# Mean Z value: 0.06541591588235296

# %%
# Move around origin
spatial_query = pc[abs( pc[:,2]-mean_Z) < 1] # keep points within 1 unit of mean Z
xyz = spatial_query[:,:3]  # XYZ coordinates
rgb=spatial_query[:,3:]  # RGB colors

# %% [markdown]
# ### Visualize with Matplotlib

# %%
ax = plt.axes(projection='3d')
# Scatter plot
ax.scatter(xyz[:,0], xyz[:,1], xyz[:,2], c = rgb/255, s=1)
plt.show()
